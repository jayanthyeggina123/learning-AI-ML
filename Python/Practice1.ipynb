# %%
name = "Jayanth"
print("Welcome", name)

a = 10
b = 20
print(a + b)

a = 10
b = 25

if a > b:
    print(a)
else:
    print(b)

    a= 7
    print("jfhfbf"+ str(a)) 
    ##- explicit 

#python 
#Python is a high-level, dynamically typed, multi-paradigm programming language.
#High-level language: Easy for humans to read and write.
#Dynamically typed: No need to declare variable types.
#Multi-paradigm: Supports object-oriented, procedural, and functional programming
# procedural, object oriented, funtional 
class Student:
    pass
age = 20 
if age >= 18:
    print("Eligible")

#variable : named location used to store data in memory 
name = "John"
age = 20
salary = 3500.50
#name = "John" creates a variable called name and stores the string "John" in it.
#age = 20 creates a variable called age and stores the integer value 20.
#salary = 3500.50 creates a variable called salary and stores the decimal (float) value 3500.50
print(name)
print(age)

##naming convention :
#Cannot start with a number.Cannot contain special characters like @, #, $, %, etc.
#Cannot use Python keywords such as if, for, class, while.Avoid using built-in function names like print, input, int, etc.
#Variable names are case-sensitive (age and Age are different).
student_name = "Alice"

#dynamic tying : we do not need to specify the data type of a variable.
#x = 10 int 
#x = "hello" str
#x = 3.14 float

#complex Literals : represents a complex number ( 2 parts)
num = 3 + 4j

# type casting[2] : process of converting one data type into another.
## implicit : PYTHON CONVERTS SMALLER data type to larger data type 
a = 10
b = 2.5
result = a + b
print(result)
#Python automatically converts 10 into 10.0.Then it adds 10.0 + 2.5.The result is 12.5.

# explicit : programmer manually converts one data type into another.
age = "20"
age = int(age)
print(age)
#"20" is a string.int(age) converts the string into an integer.Now age becomes 20.

#boolean : only 2 conditions true or false 
is_student = True
print(is_student)
#variable is_student stores the Boolean value True.

#strings : sequence of characters enclosed in single quotes (' ') or double quotes (" ")
name = "John"
city = 'Boston'
print(name)
print(city)


# operators : symbols used to perform operations on variables and values.

#arithmetic :
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)

#compariosn : 
a = 10
b = 20
print(a < b)
print(a == b)

#logical : 
age = 20
print(age > 18 and age < 30)
# both are true 

# assignment : assign or update values 
x = 5
x += 3
print(x)
#x = 5 assigns 5.
#x += 3 means x = x + 3.
#Now x becomes 8.

# input funtion : allows the user to enter data from the keyboard.
#name = input("Enter your name:john ")
#print(name)
#input() waits for the user to type something.
#Whatever the user types is stored in name.
#print(name) displays the entered value.

# int () : Converts a value into an integer.
#age = int(input("Enter age: "))
#print(age)
#input() returns a string.int() converts it into an integer.

# str() : Converts a value into a string.
age = 20
text = str(age)
print(text)
#age is an integer.str(age) converts it into a string.

# f - string : simple way to insert variables into a string.
name = "John"
age = 20
print(f"My name is {name}. I am {age} years old.")

# .format() : another way to insert variables into a string.
name = "John"
age = 20
print("My name is {}. I am {} years old.".format(name, age))
#{} are placeholders.
# .format(name, age) fills them in order.

## boolean evaluation : checks whether an expression is True or False.
print(10 > 5)
print(5 == 8)

# Branching (if, elif, else) : allows the program to make decisions based on conditions.
age = 20
if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
#if age >= 18 checks whether the age is at least 18.
#If the condition is true, it prints "Eligible".
#Otherwise, the else block runs and prints "Not Eligible".

#elif : used when you want to check multiple conditions. 
# Python checks them from top to bottom and executes the first condition that is True. 
# After finding a match, it skips the remaining conditions.
marks = 75
if marks >= 90:
    print("Grade A")
elif marks >= 70:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")

#marks = 75.Python checks marks >= 90 → False.
#Then it checks marks >= 70 → True.It prints "Grade B" and stops checking the remaining conditions.
#The elif marks >= 50 and else blocks are ignored.



#loops :
# Out:
# Welcome Jayanth
# 30
# 25
# jfhfbf7
# Eligible
# John
# 20
# 12.5
# 20
# True
# John
# Boston
# 13
# 7
# 30
# 3.3333333333333335
# True
# False
# True
# 8
# 20
# My name is John. I am 20 years old.
# My name is John. I am 20 years old.
# True
# False
# Eligible
# Grade B
